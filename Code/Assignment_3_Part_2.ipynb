# %% [markdown]
# ## Exercise 2

# %% [markdown]
# For this exercise , you will be working with the [Titanic Data Set from Kaggle](https://www.kaggle.com/c/titanic). This is a very famous data set and very often is a student's first step in Data Analytics!
#
# The Dataset has been given to you on D2L. You need to download the .csv file from your assignment folder. The above link is just for a reference story about the data.

# %% [markdown]
# 1- For this assignment, you need to perform explorotary data analysis and answer at least three hypotheses based on the dataset. You may need to use your knowledge of statiscts to analyze this data.
#
# Here are three possible hypotheses that you can define for this dataset (you can define your own hypotheses as well):
#
# - Determine if the survival rate is associated to the class of passenger
# - Determine if the survival rate is associated to the gender
# - Determine the survival rate is associated to the age
#
#
#
# 2- For each hypothesis, you need to make at least one plot.
#
# 3- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 2 of your assignment, you need to submit one jupyter notebook file and one pdf file.
#
# This will be your first end to end data analysis project. For this assignment, you will be graded on you overall analysis, and your final report.
#
# 4- Push your code and project to github and provide the link to your code here.

# %% [markdown]
# Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %% [markdown]
# **📢 GITHUB LINK FOR THIS FILE - https://github.com/bhawik-jain/Titanic_Analysis_EDA**

# %% [markdown]
# ## **🛳️ Titanic Dataset**
# The Titanic dataset is a collection of data pertaining to the passengers aboard the RMS Titanic, which famously sank on its maiden voyage on April 15, 1912. The task is to conduct Exploratory Data Analysis(EDA) and investigate minimum three key hypotheses related to passenger class, gender, and age in relation to survival rates. In doing so, we aim to uncover patterns and insights within this iconic dataset.
#
#
# ### 👉 Data fields
# * PassengerId - a unique identifier for each passenger
# * Survived - indicates whether the passenger survived (1) or did not survive (0)
# * Pclass - passenger class (1st, 2nd, or 3rd)
# * Name - the name of the passenger
# * Sex - the gender of the passenger
# * Age - the age of the passenger
# * SibSp - the number of siblings or spouses aboard
# * Parch - the number of parents or children aboard
# * Ticket - the ticket number
# * Fare - the fare paid for the ticket
# * Cabin - the cabin number
# * Embarked - the port where the passenger boarded (C = Cherbourg, Q = Queenstown, S = Southampton)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Loading Data and Overview**

# %%
df = pd.read_csv("titanic.csv")

# %%
print(df.shape)
df.head(10)
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe().drop('count')
# Out:
#       PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# mean   446.000000  0.383838  2.308642  29.699118  0.523008  0.381594
# std    257.353842  0.486592  0.836071  14.526497  1.102743  0.806057
# min      1.000000  0.000000  1.000000   0.420000  0.000000  0.000000
# 25%    223.500000  0.000000  2.000000  20.125000  0.000000  0.000000
# 50%    446.000000  0.000000  3.000000  28.000000  0.000000  0.000000
# 75%    668.500000  1.000000  3.000000  38.000000  1.000000  0.000000
# max    891.000000  1.000000  3.000000  80.000000  8.000000  6.000000
#
#             Fare
# mean   32.204208
# std    49.693429
# min     0.000000
# 25%     7.910400
# 50%    14.454200
# 75%    31.000000
# max   512.329200

# %%
df.describe(include='object').drop('count')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * The data has 891 rows and 12 columns.
# * Out of 891 values, 687 values are missing in 'Cabin' feature(70% of the total data is missing).
# * 'Age' has 177 missing values and  values are missing in 'Embarked'.
# * There is no duplicate entry in the dataset.

# %% [markdown]
# ## **EDA**

# %% [markdown]
# ### 1. Data Visualization

# %% [markdown]
# #### 1.1 Survived

# %%
axis = sns.countplot(x='Survived',data=df)
plt.title('Countplot of Survived Categories')
axis.bar_label(axis.containers[0]) # Labeling the bars with counts
# Out:
# [Text(0, 0, '549'), Text(0, 0, '342')]

# %%
category_cnt = df['Survived'].value_counts()
l = category_cnt.index # Extracting unique categories
s = category_cnt.values # Extracting size of each category
p = (size / sum(size)) * 100 # Calculating percentages of each category

plt.pie(size, labels=label, autopct='%1.1f%%')
plt.title('Pie Chart of Categories with percentages')
plt.show()

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * Out of 891 passengers, 342 survived i.e only 38.4% of the total passengers survived the crash.
# * Dataset is not balanced.

# %% [markdown]
# #### 1.2 Pclass

# %%
axis = sns.countplot(x='Pclass',data=df)
plt.title('Countplot of Pclass Categories')
axis.bar_label(axis.containers[0])
# Out:
# [Text(0, 0, '216'), Text(0, 0, '184'), Text(0, 0, '491')]

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * 3rd Class has the highest number of passengers, with 491 individuals indicating that larger proportion of passengers travelled from 3rd Class
# * 1st Class and 2nd Class have relatively smaller counts compared to 3rd Class.

# %% [markdown]
# #### 1.3 Sex

# %%
axis = sns.countplot(x='Sex',data=df)
plt.title('Countplot of Sex Categories')
axis.bar_label(axis.containers[0])
# Out:
# [Text(0, 0, '577'), Text(0, 0, '314')]

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * 'Male' is the dominant category with a significantly higher count compared to 'female'.

# %% [markdown]
# #### 1.3 Age

# %%
sns.histplot(df['Age'], kde=True)  # KDE adds a kernel density estimate
plt.title('Age Distribution')
plt.xlim(0)
plt.show()

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * Most of the passengers are aged between 20 to 40.

# %% [markdown]
# ### 2. Exploring Feature Associations with 'Survived'

# %% [markdown]
# #### 2.1 Survival rate association with class of passenger

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * Passengers travelling in lower class like 3rd has lower chances to survive.
# * Better the class of passenger, Higher the chances of survival.

# %% [markdown]
# #### 2.2 Survival rate association with gender

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * We have seen above that the number of men on the ship is lot more than the number of women, still the number of women survived is almost twice the number of males survived.
# * Female has a much higher chance of survival than men.

# %% [markdown]
# #### 2.3 Survival rate association with age

# %%
sns.boxplot(data=df, y="Survived", x="Age", orient="h")
plt.title('Box Plot of Age by Survied')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age by Survied')

# %% [markdown]
# There are some outliers present in Age feature. We can further analyze age feature by using its PDF.

# %%
g = sns.FacetGrid(df, hue="Survived", height=4)
g.map_dataframe(sns.histplot, x="Age", kde=True)
g.set_axis_labels("Age", "Count")
g.add_legend()
plt.xlim(0)
plt.show()

# %% [markdown]
# **⭐ OBSERVATIONS**
#
# * Passengers under 10, had a higher survival rate indicating a positive association between age under 20 and survival. However, among passengers aged above 10, the survival rate was lower.
# * Passengers with an age greater than 65 almost all of them could not survive.
